# %%
import csv
import os
from collections import defaultdict

# Directories
PREP_FOLDER = 'prep'
REPORT_FOLDER = 'report'

# Ensure the directories exist
os.makedirs(PREP_FOLDER, exist_ok=True)
os.makedirs(REPORT_FOLDER, exist_ok=True)

# Function to read data from a CSV file
def read_csv(filename):
    filepath = os.path.join(PREP_FOLDER, filename)
    with open(filepath, mode='r', newline='') as file:
        reader = csv.DictReader(file)
        return list(reader)

# Function to save data to a CSV file
def save_data_to_csv(data, columns, filename):
    file_path = os.path.join(REPORT_FOLDER, filename)  # Save to the report folder
    
    with open(file_path, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(columns)  # Write the header
        writer.writerows(data)    # Write the data

    print(f"Data saved to {file_path}")

# 1. User Enrollment Report
def generate_user_enrollment_report():
    users = read_csv('users.csv')
    course_assignments = read_csv('course_assignments.csv')
    courses = read_csv('courses.csv')

    enrollment_data = []
    for assignment in course_assignments:
        user_id = assignment['user_id']
        course_id = assignment['course_id']
        
        user = next((u for u in users if u['id'] == user_id), None)
        course = next((c for c in courses if c['id'] == course_id), None)

        if user and course:
            enrollment_data.append([
                user['name'],
                course['title'],
                assignment['progress'],
                assignment['assignment_date']
            ])
    
    save_data_to_csv(enrollment_data, ['User Name', 'Course Title', 'Progress (%)', 'Assignment Date'], 'user_enrollment_report.csv')

# 2. User Performance Report
def generate_user_performance_report():
    users = read_csv('users.csv')
    course_assignments = read_csv('course_assignments.csv')
    courses = read_csv('courses.csv')
    performance_ratings = read_csv('performance_ratings.csv')

    performance_data = []
    for assignment in course_assignments:
        user_id = assignment['user_id']
        course_id = assignment['course_id']
        
        user = next((u for u in users if u['id'] == user_id), None)
        course = next((c for c in courses if c['id'] == course_id), None)

        rating = next((r for r in performance_ratings if r['assignment_id'] == assignment['id']), None)

        if user and course:
            performance_data.append([
                user['name'],
                course['title'],
                assignment['quiz_score'],
                assignment['engagement_score'],
                assignment['assignment_grade'],
                rating['rating'] if rating else 'N/A'
            ])
    
    save_data_to_csv(performance_data, ['User Name', 'Course Title', 'Quiz Score', 'Engagement Score', 'Assignment Grade', 'Overall Rating'], 'user_performance_report.csv')

# 3. Course Completion and Certification Report
def generate_course_completion_report():
    users = read_csv('users.csv')
    course_assignments = read_csv('course_assignments.csv')
    courses = read_csv('courses.csv')
    certificates = read_csv('certificates.csv')

    completion_data = []
    for assignment in course_assignments:
        if assignment['progress'] == '100':  # Only show courses with 100% progress
            user_id = assignment['user_id']
            course_id = assignment['course_id']
            
            user = next((u for u in users if u['id'] == user_id), None)
            course = next((c for c in courses if c['id'] == course_id), None)
            cert = next((cert for cert in certificates if cert['assignment_id'] == assignment['id']), None)

            if user and course:
                completion_data.append([
                    user['name'],
                    course['title'],
                    assignment['progress'],
                    cert['is_certified'] if cert else 'N/A'
                ])
    
    save_data_to_csv(completion_data, ['User Name', 'Course Title', 'Progress (%)', 'Is Certified'], 'course_completion_report.csv')

# 4. Learning Path Summary Report
def generate_learning_path_summary_report():
    users = read_csv('users.csv')
    performance_summaries = read_csv('performance_summaries.csv')
    learning_paths = read_csv('learning_paths.csv')

    summary_data = []
    for summary in performance_summaries:
        user_id = summary['user_id']
        learning_path_id = summary['learning_path_id']

        user = next((u for u in users if u['id'] == user_id), None)
        learning_path = next((lp for lp in learning_paths if lp['id'] == learning_path_id), None)

        if user and learning_path:
            summary_data.append([
                user['name'],
                learning_path['title'],
                summary['average_rating']
            ])
    
    save_data_to_csv(summary_data, ['User Name', 'Learning Path Title', 'Average Rating'], 'learning_path_summary_report.csv')

# 5. Course Ratings Report
def generate_course_ratings_report():
    courses = read_csv('courses.csv')
    course_assignments = read_csv('course_assignments.csv')
    performance_ratings = read_csv('performance_ratings.csv')

    ratings_data = defaultdict(list)

    for assignment in course_assignments:
        course_id = assignment['course_id']
        rating = next((r for r in performance_ratings if r['assignment_id'] == assignment['id']), None)

        if rating:
            ratings_data[course_id].append(float(rating['rating']))

    average_ratings_data = []
    for course in courses:
        course_id = course['id']
        if course_id in ratings_data:
            avg_rating = sum(ratings_data[course_id]) / len(ratings_data[course_id])
            average_ratings_data.append([course['title'], avg_rating])

    save_data_to_csv(average_ratings_data, ['Course Title', 'Average Rating'], 'course_ratings_report.csv')

# 6. Course Enrollment and Certification Report
def generate_course_enrollment_certification_report():
    courses = read_csv('courses.csv')
    course_assignments = read_csv('course_assignments.csv')
    certificates = read_csv('certificates.csv')

    enrollment_data = defaultdict(lambda: {'total_enrolled': 0, 'total_certified': 0})

    for assignment in course_assignments:
        course_id = assignment['course_id']
        enrollment_data[course_id]['total_enrolled'] += 1
        cert = next((cert for cert in certificates if cert['assignment_id'] == assignment['id']), None)
        if cert and cert['is_certified'] == 'True':
            enrollment_data[course_id]['total_certified'] += 1

    report_data = []
    for course_id, counts in enrollment_data.items():
        course = next((c for c in courses if c['id'] == course_id), None)
        if course:
            report_data.append([course['title'], counts['total_enrolled'], counts['total_certified']])

    save_data_to_csv(report_data, ['Course Title', 'Total Enrolled', 'Total Certified'], 'course_enrollment_certification_report.csv')

# 7. Learning Path Enrollment and Certification Report
def generate_learning_path_enrollment_certification_report():
    learning_paths = read_csv('learning_paths.csv')
    course_learning_paths = read_csv('course_learning_paths.csv')
    course_assignments = read_csv('course_assignments.csv')
    certificates = read_csv('certificates.csv')

    enrollment_data = defaultdict(lambda: {'total_enrolled': 0, 'total_certified': 0})

    for clp in course_learning_paths:
        course_id = clp['course_id']
        enrolled_assignments = [ca for ca in course_assignments if ca['course_id'] == course_id]
        
        for assignment in enrolled_assignments:
            enrollment_data[clp['learning_path_id']]['total_enrolled'] += 1
            cert = next((cert for cert in certificates if cert['assignment_id'] == assignment['id']), None)
            if cert and cert['is_certified'] == 'True':
                enrollment_data[clp['learning_path_id']]['total_certified'] += 1

    report_data = []
    for learning_path in learning_paths:
        lp_id = learning_path['id']
        counts = enrollment_data[lp_id]
        report_data.append([learning_path['title'], counts['total_enrolled'], counts['total_certified']])

    save_data_to_csv(report_data, ['Learning Path Title', 'Total Enrolled', 'Total Certified'], 'learning_path_enrollment_certification_report.csv')

# Generate all reports
generate_user_enrollment_report()
generate_user_performance_report()
generate_course_completion_report()
generate_learning_path_summary_report()
generate_course_ratings_report()
generate_course_enrollment_certification_report()
generate_learning_path_enrollment_certification_report()

print("All reports have been generated in the 'report' folder.")
# Out:
# Data saved to report\user_enrollment_report.csv
# Data saved to report\user_performance_report.csv
# Data saved to report\course_completion_report.csv
# Data saved to report\learning_path_summary_report.csv
# Data saved to report\course_ratings_report.csv
# Data saved to report\course_enrollment_certification_report.csv
# Data saved to report\learning_path_enrollment_certification_report.csv
# All reports have been generated in the 'report' folder.
